# %% [markdown]
# # Solução da Equação de Poisson Unidimensional por Diferenças finitas

# %% [markdown]
# $$ \Delta u = \nabla^{2} u  ~  \Omega$$
# $$  \frac{U_{i} - U_{i - 1}}{\Delta x}  $$
# Discretização da equação por diferenças centrais

# %%
# Importações de pacotes
import numpy as np

# Construção da malha 
xi, xf = 0, 1
N = 5 # Número de pontos internos
x, dx = np.linspace(xi, xf, N+1, retstep = True, endpoint = True)

print(dx)
print(x)
# Out:
# 0.2
# [0.  0.2 0.4 0.6 0.8 1. ]
